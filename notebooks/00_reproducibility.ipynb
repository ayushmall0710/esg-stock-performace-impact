# %% [markdown]
# # Reproducibility Checklist
#
# This notebook installs dependencies and re-runs the full ESG pipeline using the provided scripts. Use it to regenerate data, analysis outputs, and figures in a clean environment.

# %% [markdown]
# ## Prerequisites
# - Python 3.8+ and network access for Kaggle/Yahoo/FRED downloads.
# - Kaggle API credentials in `~/.kaggle/kaggle.json` **or** set `KAGGLE_USERNAME` / `KAGGLE_KEY` env vars.
# - Optional: `FRED_API_KEY` in `.env` for automated risk-free retrieval (manual fallback available).
# - Run from the `notebooks/` directory so relative paths to `../scripts` and `../data` work.

# %%
# Install project requirements (idempotent)
# !python3 -m pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: numpy>=1.24.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 2)) (2.3.5)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 3)) (0.14.5)
# Requirement already satisfied: scipy>=1.10.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: seaborn>=0.12.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: yfinance>=0.2.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 7)) (0.2.66)
# Requirement already satisfied: kaggle>=1.5.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 8)) (1.8.2)
# Requirement already satisfied: requests>=2.28.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 9)) (2.32.5)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 10)) (1.2.1)
# Requirement already satisfied: jupyter>=1.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: notebook>=6.5.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 12)) (7.5.0)
# Requirement already satisfied: openpyxl>=3.1.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 13)) (3.1.5)
# Requirement already satisfied: pandas-datareader>=0.10.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from -r ../requirements.txt (line 14)) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from statsmodels>=0.14.0->-r ../requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from statsmodels>=0.14.0->-r ../requirements.txt (line 3)) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 5)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 5)) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 5)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 5)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 5)) (3.2.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.7 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (6.33.1)
# Requirement already satisfied: websockets>=13.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from yfinance>=0.2.0->-r ../requirements.txt (line 7)) (15.0.1)
# Requirement already satisfied: black>=24.10.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (25.11.0)
# Requirement already satisfied: bleach in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (6.3.0)
# Requirement already satisfied: kagglesdk in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (0.1.13)
# Requirement already satisfied: mypy>=1.15.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (1.19.0)
# Requirement already satisfied: python-slugify in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (8.0.4)
# Requirement already satisfied: setuptools>=21.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (80.9.0)
# Requirement already satisfied: six>=1.10 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: tqdm in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (4.67.1)
# Requirement already satisfied: types-requests in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from kaggle>=1.5.0->-r ../requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from requests>=2.28.0->-r ../requirements.txt (line 9)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from requests>=2.28.0->-r ../requirements.txt (line 9)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from requests>=2.28.0->-r ../requirements.txt (line 9)) (2025.11.12)
# Requirement already satisfied: jupyter-console in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 11)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 11)) (7.16.6)
# Requirement already satisfied: ipykernel in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 11)) (7.1.0)
# Requirement already satisfied: ipywidgets in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 11)) (8.1.8)
# Requirement already satisfied: jupyterlab in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter>=1.0.0->-r ../requirements.txt (line 11)) (4.5.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from notebook>=6.5.0->-r ../requirements.txt (line 12)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from notebook>=6.5.0->-r ../requirements.txt (line 12)) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from notebook>=6.5.0->-r ../requirements.txt (line 12)) (6.5.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (4.12.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.23.1)
# Requirement already satisfied: pyzmq>=24 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyterlab->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (2.3.0)
# Requirement already satisfied: httpcore==1.* in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (4.25.1)
# Requirement already satisfied: et-xmlfile in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from openpyxl>=3.1.0->-r ../requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: lxml in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from pandas-datareader>=0.10.0->-r ../requirements.txt (line 14)) (6.0.2)
# Requirement already satisfied: argon2-cffi-bindings in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (25.1.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.0->-r ../requirements.txt (line 7)) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.0->-r ../requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: click>=8.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from black>=24.10.0->kaggle>=1.5.0->-r ../requirements.txt (line 8)) (8.3.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from black>=24.10.0->kaggle>=1.5.0->-r ../requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from black>=24.10.0->kaggle>=1.5.0->-r ../requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: pytokens>=0.3.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from black>=24.10.0->kaggle>=1.5.0->-r ../requirements.txt (line 8)) (0.3.0)
# Requirement already satisfied: cffi>=1.12.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from curl_cffi>=0.7->yfinance>=0.2.0->-r ../requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.0->-r ../requirements.txt (line 7)) (2.23)
# Requirement already satisfied: appnope>=0.1.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (9.7.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (7.1.3)
# Requirement already satisfied: decorator>=4.3.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (25.10.0)
# Requirement already satisfied: librt>=0.6.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from mypy>=1.15.0->kaggle>=1.5.0->-r ../requirements.txt (line 8)) (0.6.3)
# Requirement already satisfied: defusedxml in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from bleach->kaggle>=1.5.0->-r ../requirements.txt (line 8)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipywidgets->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from ipywidgets->jupyter>=1.0.0->-r ../requirements.txt (line 11)) (3.0.16)
# Requirement already satisfied: arrow>=0.15.0 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.0->-r ../requirements.txt (line 12)) (1.4.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages (from python-slugify->kaggle>=1.5.0->-r ../requirements.txt (line 8)) (1.3)

# %%
# Optional: verify Kaggle credentials are available
# !ls -l ~/.kaggle/kaggle.json || echo "kaggle.json not found; ensure env vars are set"
# Out:
# ls: /Users/ayush/.kaggle/kaggle.json: No such file or directory
# kaggle.json not found; ensure env vars are set

# %% [markdown]
# ## Run pipeline scripts
# Order: download → process → feature engineering → analysis → figures.

# %%
# 1) Download raw data (Kaggle, Yahoo Finance, FRED)
# !python ../scripts/download_data.py
# Out:
# [INFO] Loaded environment variables from /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/notebooks/../.env
#
# ============================================================
# ESG STOCK PERFORMANCE ANALYSIS - DATA DOWNLOAD
# ============================================================
#
#
# ### STEP 1/4: Kaggle Dataset ###
# ============================================================
# Downloading S&P 500 ESG and Stocks Data from Kaggle
# ============================================================
#
# [INFO] Using Kaggle credentials from environment variables
#
# 📥 Downloading dataset: rikinzala/s-and-p-500-esg-and-stocks-data-2023-24
# 📁 Saving to: data/raw
#
# Dataset URL: https://www.kaggle.com/datasets/rikinzala/s-and-p-500-esg-and-stocks-data-2023-24
# License(s): GPL-3.0
# Downloading s-and-p-500-esg-and-stocks-data-2023-24.zip to data/raw
#
#
# [OK] Found: sp500_esg_data.csv (0.05 MB)
# [OK] Found: sp500_price_data.csv (3.03 MB)
#
# [OK] Kaggle dataset downloaded successfully!
#
#
# ### STEP 2/4: FRED Treasury Rate ###
# ============================================================
# Downloading U.S. 3-Month Treasury Rate from FRED
# ============================================================
#
# [FETCHING] Using FRED API to fetch data...
# [DATE] Date range: 2023-09-01 to 2024-08-31
#
# [OK] Data saved to: data/raw/DGS3MO.csv
# [INFO] Records downloaded: 261
# [STATS] Date range: 2023-09-01 00:00:00 to 2024-08-30 00:00:00
#
# Data preview:
#             DGS3MO
# DATE
# 2023-09-01    5.53
# 2023-09-04     NaN
# 2023-09-05    5.55
# 2023-09-06    5.55
# 2023-09-07    5.53
#
# Missing values: 11
#
#
# ### STEP 3/4: S&P 500 Index Data ###
# ============================================================
# Downloading S&P 500 Index Data from Yahoo Finance
# ============================================================
#
# [FETCHING] Fetching S&P 500 (^GSPC) data...
# [DATE] Date range: 2023-09-01 to 2024-08-31
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/notebooks/../src/data_acquisition/fetch_market_data.py:39: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download("^GSPC", start=start_date, end=end_date, progress=False)
#
# [OK] Data saved to: data/raw/sp500_index.csv
# [INFO] Trading days: 251
# [STATS] Date range: 2023-09-01 to 2024-08-30
#
# Price summary:
# 	Opening price range: $4139.39 - $5644.09
# 	Closing price range: $4117.37 - $5667.20
#
# Data preview:
# Price             Close         High          Low         Open      Volume
# Date
# 2023-09-01  4515.770020  4541.250000  4501.350098  4530.600098  3246260000
# 2023-09-05  4496.830078  4514.290039  4496.009766  4510.060059  3526250000
# 2023-09-06  4465.479980  4490.350098  4442.379883  4490.350098  3418850000
# 2023-09-07  4451.140137  4457.810059  4430.459961  4434.549805  3763760000
# 2023-09-08  4457.490234  4473.529785  4448.379883  4451.299805  3259290000
#
#
# ### STEP 4/4: Company Information ###
#
# [LOADING] Loading tickers from: data/raw/sp500_esg_data.csv
# [OK] Found 426 unique tickers
#
# [INFO] Fetching company info for 426 tickers...
# [NOTE] This may take several minutes due to rate limiting...
# ============================================================
# Fetching Company Info from Yahoo Finance
# ============================================================
#
# [INFO] Fetching data for 426 companies...
# [NOTE]  Delay between requests: 0.5s
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ANSS"}}}
# 	Progress: 50/426 (49 successful, 0 failed)
# 	Progress: 100/426 (99 successful, 0 failed)
# 	Progress: 150/426 (149 successful, 0 failed)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: HES"}}}
# 	Progress: 200/426 (199 successful, 0 failed)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: JNPR"}}}
# 	Progress: 250/426 (249 successful, 0 failed)
# 	Progress: 300/426 (299 successful, 0 failed)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: PARA"}}}
# 	Progress: 350/426 (349 successful, 0 failed)
# 	Progress: 400/426 (399 successful, 0 failed)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: WBA"}}}
#
# [OK] Data saved to: data/raw/company_info.csv
#
# [INFO] Summary:
# 	Total companies: 426
# 	Successfully fetched: 426
# 	Failed: 0
#
# [STATS] Sector distribution:
# 	Technology: 61
# 	Financial Services: 60
# 	Industrials: 57
# 	Healthcare: 51
# 	Consumer Cyclical: 51
# 	Consumer Defensive: 33
# 	Utilities: 28
# 	Real Estate: 28
# 	Basic Materials: 19
# 	Energy: 18
#
# 💰 Market Cap statistics (in billions):
# 	Mean: $134.46B
# 	Median: $39.55B
# 	Min: $1.64B
# 	Max: $4517.59B
#
#
# ============================================================
# DOWNLOAD SUMMARY
# ============================================================
#
# Status:
# 	[OK] Kaggle Dataset (ESG & Prices)
# 	[OK] FRED Treasury Rate
# 	[OK] S&P 500 Index
# 	[OK] Company Information
#
# Overall: 4/4 data sources downloaded successfully
#
# [SUCCESS] All data downloaded successfully!
#
# Next steps:
# 	python scripts/process_data.py
#
# Data files saved to: data/raw/
# ============================================================

# %%
# 2) Process data (clean ESG, prices, returns; align dates; risk-free)
# !python ../scripts/process_data.py
# Out:
# ============================================================
# ESG STOCK PERFORMANCE ANALYSIS - DATA PROCESSING
# ============================================================
#
#
# ### STEP 1/6: Clean ESG Data ###
# ============================================================
# Cleaning ESG Data
# ============================================================
#
# [LOADING] Loading data from: data/raw/sp500_esg_data.csv
# [OK] Loaded 426 records
#
# Columns: ['Symbol', 'Full Name', 'GICS Sector', 'GICS Sub-Industry', 'environmentScore', 'socialScore', 'governanceScore', 'totalEsg', 'highestControversy', 'percentile', 'ratingYear', 'ratingMonth', 'marketCap', 'beta', 'overallRisk']
#
# [OK] Using 'Symbol' as ticker column
#
# [PROCESSING] Standardizing ticker symbols...
# [PROCESSING] Removing duplicate tickers...
#
# [INFO] Identified ESG columns: ['environmentScore', 'socialScore', 'governanceScore']
#
# [CHECKING] Checking for missing values...
# 	environmentScore: 0 (0.0%)
# 	socialScore: 0 (0.0%)
# 	governanceScore: 0 (0.0%)
#
# [STATS] Rows with any missing ESG scores: 0 (0.0%)
# 	Strategy: Dropping rows with missing values (< 5% threshold)
#
# [CHECKING] Validating ESG score ranges...
# 	environmentScore: 0.00 - 24.98
# 	socialScore: 0.76 - 22.48
# 	governanceScore: 2.96 - 19.43
#
# ============================================================
# CLEANING SUMMARY
# ============================================================
# Original records: 426
# Final records: 426
# Records removed: 0 (0.0%)
#
# [OK] Cleaned data saved to: data/processed/esg_cleaned.csv
#
# Data preview:
#   Symbol  environmentScore  socialScore  governanceScore
# 0      A              1.12         6.42             6.10
# 1    AAL              9.94        11.65             4.76
# 2   AAPL              0.46         7.39             9.37
# 3   ABBV              2.38        17.19            10.36
# 4    ABT              2.27        14.24             8.33
#
#
# ### STEP 2/6: Clean Price Data ###
# ============================================================
# Cleaning Price Data
# ============================================================
#
# [LOADING] Loading data from: data/raw/sp500_price_data.csv
# [OK] Loaded 418 records
#
# Columns: ['Date', 'A', 'AAL', 'AAPL', 'ABBV', 'ABT', 'ACGL', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES', 'AFL', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALL', 'ALLE', 'AMAT', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'AOS', 'APA', 'APD', 'APH', 'APTV', 'ARE', 'ATO', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO', 'BA', 'BAC', 'BALL', 'BAX', 'BBWI', 'BBY', 'BDX', 'BEN', 'BG', 'BIIB', 'BIO', 'BK', 'BKNG', 'BLK', 'BMY', 'BR', 'BRO', 'BSX', 'BWA', 'BX', 'BXP', 'C', 'CAG', 'CAH', 'CAT', 'CB', 'CBOE', 'CBRE', 'CCI', 'CCL', 'CDNS', 'CDW', 'CE', 'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COO', 'COP', 'COR', 'COST', 'CPB', 'CPRT', 'CPT', 'CRM', 'CSCO', 'CSGP', 'CSX', 'CTAS', 'CTRA', 'CTSH', 'CVS', 'CVX', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DLR', 'DLTR', 'DOV', 'DPZ', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DXCM', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EG', 'EIX', 'EL', 'ELV', 'EMN', 'EMR', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESS', 'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST', 'FCX', 'FDS', 'FDX', 'FE', 'FFIV', 'FI', 'FIS', 'FITB', 'FMC', 'FRT', 'FTNT', 'FTV', 'GD', 'GE', 'GEN', 'GILD', 'GIS', 'GL', 'GLW', 'GM', 'GOOGL', 'GPC', 'GPN', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HBAN', 'HCA', 'HD', 'HES', 'HIG', 'HLT', 'HOLX', 'HON', 'HPE', 'HPQ', 'HRL', 'HSIC', 'HST', 'HSY', 'HUBB', 'HUM', 'IBM', 'ICE', 'IDXX', 'IEX', 'IFF', 'INCY', 'INTC', 'INTU', 'IP', 'IPG', 'IQV', 'IRM', 'ISRG', 'IT', 'ITW', 'IVZ', 'J', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'JPM', 'K', 'KEY', 'KEYS', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX', 'KO', 'KR', 'L', 'LDOS', 'LEN', 'LH', 'LKQ', 'LLY', 'LMT', 'LNT', 'LOW', 'LRCX', 'LULU', 'LUV', 'LVS', 'LYB', 'MA', 'MAA', 'MAR', 'MAS', 'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'META', 'MGM', 'MHK', 'MKC', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOS', 'MPC', 'MRK', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'NCLH', 'NDAQ', 'NDSN', 'NEE', 'NEM', 'NFLX', 'NI', 'NKE', 'NOC', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NVR', 'NWSA', 'NXPI', 'O', 'OKE', 'OMC', 'ON', 'ORCL', 'ORLY', 'OXY', 'PANW', 'PARA', 'PAYX', 'PCAR', 'PCG', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH', 'PHM', 'PKG', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL', 'PRU', 'PSA', 'PSX', 'PTC', 'PWR', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'REG', 'REGN', 'RF', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG', 'RVTY', 'SBAC', 'SBUX', 'SCHW', 'SHW', 'SJM', 'SLB', 'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SRE', 'STLD', 'STT', 'STX', 'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG', 'TEL', 'TER', 'TFX', 'TGT', 'TJX', 'TMO', 'TMUS', 'TPR', 'TRGP', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TT', 'TXN', 'TXT', 'UAL', 'UDR', 'UHS', 'ULTA', 'UNH', 'UNP', 'UPS', 'URI', 'USB', 'V', 'VLO', 'VMC', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAB', 'WAT', 'WBA', 'WDC', 'WEC', 'WELL', 'WFC', 'WM', 'WMB', 'WMT', 'WRB', 'WTW', 'WY', 'WYNN', 'XEL', 'XOM', 'XYL', 'YUM', 'ZBH', 'ZTS']
#
# [PROCESSING] Parsing dates from column: 'Date'
# [PROCESSING] Filtering to date range: 2023-09-01 to 2024-08-31
# 	Kept 251 / 418 records
# [PROCESSING] Sorting by date...
#
# [INFO] Identified price columns: ['LOW']
#
# [INFO] Data format: Wide (one row per date, columns per ticker)
# 	Converting to long format...
#
# [CHECKING] Checking for infinite values...
#
# ============================================================
# CLEANING SUMMARY
# ============================================================
# Date range: 2023-09-01 to 2024-08-30
# Trading days: 251
# Tickers: 426
# Total records: 106926
#
# [OK] Cleaned data saved to: data/processed/prices_cleaned.csv
#
# Data preview:
#                        Date Ticker       Close
# 0 2023-09-01 00:00:00+00:00      A  121.910004
# 1 2023-09-05 00:00:00+00:00      A  118.730003
# 2 2023-09-06 00:00:00+00:00      A  117.940002
# 3 2023-09-07 00:00:00+00:00      A  116.260002
# 4 2023-09-08 00:00:00+00:00      A  113.989998
# 5 2023-09-11 00:00:00+00:00      A  113.099998
# 6 2023-09-12 00:00:00+00:00      A  112.779999
# 7 2023-09-13 00:00:00+00:00      A  113.430000
# 8 2023-09-14 00:00:00+00:00      A  114.879997
# 9 2023-09-15 00:00:00+00:00      A  115.910004
#
#
# ### STEP 3/6: Calculate Returns ###
#
# --- Stock Returns ---
# ============================================================
# Calculating Daily Returns
# ============================================================
#
# [LOADING] Loading data from: data/processed/prices_cleaned.csv
# [OK] Loaded 106926 records
#
# [OK] Using columns:
# 	Date: Date
# 	Ticker: Ticker
# 	Price: Close
#
# [PROCESSING] Calculating simple returns...
# [PROCESSING] Removing NaN values from first day...
# 	Removed 426 rows
#
# [CHECKING] Checking for problematic returns...
#
# [STATS] Return Statistics:
# 	Mean daily return: 0.0729%
# 	Median daily return: 0.0900%
# 	Std dev: 1.7117%
# 	Min: -53.14%
# 	Max: 25.30%
#
# [STATS] Return Distribution:
# count    106500.000000
# mean          0.000729
# std           0.017117
# min          -0.531402
# 25%          -0.007608
# 50%           0.000900
# 75%           0.009039
# max           0.253001
# Name: Return, dtype: float64
#
# [OK] Returns data saved to: data/processed/returns.csv
#
# Data preview:
#                         Date Ticker       Close    Return
# 1  2023-09-05 00:00:00+00:00      A  118.730003 -0.026085
# 2  2023-09-06 00:00:00+00:00      A  117.940002 -0.006654
# 3  2023-09-07 00:00:00+00:00      A  116.260002 -0.014245
# 4  2023-09-08 00:00:00+00:00      A  113.989998 -0.019525
# 5  2023-09-11 00:00:00+00:00      A  113.099998 -0.007808
# 6  2023-09-12 00:00:00+00:00      A  112.779999 -0.002829
# 7  2023-09-13 00:00:00+00:00      A  113.430000  0.005763
# 8  2023-09-14 00:00:00+00:00      A  114.879997  0.012783
# 9  2023-09-15 00:00:00+00:00      A  115.910004  0.008966
# 10 2023-09-18 00:00:00+00:00      A  112.690002 -0.027780
#
# ============================================================
# CALCULATION SUMMARY
# ============================================================
# Total return records: 106500
# Tickers: 426
# Date range: 2023-09-05 to 2024-08-30
# Return type: simple
#
# --- Market Returns ---
#
# ============================================================
# Calculating Market Returns (S&P 500)
# ============================================================
#
# [LOADING] Loading data from: data/raw/sp500_index.csv
# [OK] Loaded 251 records
#
# [STATS] Market Return Statistics:
# 	Mean daily return: 0.0926%
# 	Std dev: 0.7842%
# 	Annualized return: 26.28%
# 	Annualized volatility: 12.45%
#
# [OK] Market returns saved to: data/processed/market_returns.csv
#
#
# ### STEP 4/6: Process Risk-Free Rate ###
# ============================================================
# Processing Risk-Free Rate Data
# ============================================================
#
# [LOADING] Loading data from: data/raw/DGS3MO.csv
# [OK] Loaded 261 records
#
# Columns: ['DATE', 'DGS3MO']
#
# [OK] Using columns:
# 	Date: DATE
# 	Rate: DGS3MO
#
# [PROCESSING] Handling missing values...
# 	Found 11 missing values
# 	Forward-filling gaps...
#
# [PROCESSING] Converting annual rate to daily rate...
# 	Assuming 252 trading days per year
#
# [LOADING] Loading trading days from: data/processed/returns.csv
# [OK] Found 250 unique trading days
#
# [PROCESSING] Aligning risk-free rate with trading days...
# 	Aligned to 250 trading days
#
# [STATS] Risk-Free Rate Statistics:
# 	Annual rate range: 5.2100% - 5.6300%
# 	Mean annual rate: 5.4673%
# 	Mean daily rate: 0.000211 (0.0211%)
# 	Annualized daily rate: 5.4673% (should match annual rate)
#
# [OK] Processed data saved to: data/processed/risk_free_rate.csv
#
# Data preview:
#                        Date  Annual_Rate  Daily_RF_Rate
# 0 2023-09-05 00:00:00+00:00         5.55       0.000214
# 1 2023-09-06 00:00:00+00:00         5.55       0.000214
# 2 2023-09-07 00:00:00+00:00         5.53       0.000214
# 3 2023-09-08 00:00:00+00:00         5.55       0.000214
# 4 2023-09-11 00:00:00+00:00         5.55       0.000214
# 5 2023-09-12 00:00:00+00:00         5.56       0.000215
# 6 2023-09-13 00:00:00+00:00         5.55       0.000214
# 7 2023-09-14 00:00:00+00:00         5.55       0.000214
# 8 2023-09-15 00:00:00+00:00         5.56       0.000215
# 9 2023-09-18 00:00:00+00:00         5.55       0.000214
#
# ============================================================
# PROCESSING SUMMARY
# ============================================================
# Date range: 2023-09-05 to 2024-08-30
# Total days: 250
# Average annual rate: 5.4673%
# Average daily rate: 0.0211%
#
#
# ### STEP 5/6: Merge All Datasets ###
# ============================================================
# Merging All Datasets
# ============================================================
#
# [LOADING] Step 1: Loading returns data...
# [OK] Loaded 106500 records
# 	Tickers: 426
# 	Date range: 2023-09-05 to 2024-08-30
#
# [LOADING] Step 2: Loading and merging ESG data...
# [OK] Loaded 426 companies
# 	After merge: 106500 records, 426 tickers
#
# [LOADING] Step 3: Loading and merging risk-free rate...
# [OK] Loaded 250 dates
# 	After merge: 106500 records
#
# [LOADING] Step 4: Loading and merging market returns...
# [OK] Loaded 250 dates
# 	After merge: 106500 records
#
# [LOADING] Step 5: Loading and merging company information...
# [OK] Loaded 426 companies
# 	After merge: 106500 records
# 	[WARNING]  Missing market cap for 1750 records
#
# [PROCESSING] Calculating excess returns...
#
# [CHECKING] Final validation...
#
# ============================================================
# MERGE SUMMARY
# ============================================================
# Total records: 106500
# Unique tickers: 426
# Date range: 2023-09-05 to 2024-08-30
# Trading days: 250
#
# Data completeness:
# 	Returns: 106500 / 106500
# 	ESG scores: 106500 / 106500
# 	Risk-free rate: 106500 / 106500
# 	Market returns: 106500 / 106500
# 	Market cap: 104750 / 106500
#
# [OK] Master dataset saved to: data/final/master_dataset.csv
#
# Data preview:
#                        Date Ticker  ...                Industry  Excess_Return
# 0 2023-09-05 00:00:00+00:00      A  ...  Diagnostics & Research      -0.026299
# 1 2023-09-06 00:00:00+00:00      A  ...  Diagnostics & Research      -0.006868
# 2 2023-09-07 00:00:00+00:00      A  ...  Diagnostics & Research      -0.014458
# 3 2023-09-08 00:00:00+00:00      A  ...  Diagnostics & Research      -0.019740
# 4 2023-09-11 00:00:00+00:00      A  ...  Diagnostics & Research      -0.008022
#
# [5 rows x 24 columns]
#
# Column summary:
# Total columns: 24
# Columns: ['Date', 'Ticker', 'Close', 'Return', 'Full Name', 'GICS Sector', 'GICS Sub-Industry', 'environmentScore', 'socialScore', 'governanceScore', 'totalEsg', 'highestControversy', 'percentile', 'ratingYear', 'ratingMonth', 'marketCap', 'beta', 'overallRisk', 'Daily_RF_Rate', 'Market_Return', 'Market_Cap', 'Sector', 'Industry', 'Excess_Return']
#
#
# ### STEP 6/6: Data Quality Report ###
# ============================================================
#
# Master Dataset Statistics:
# 	Total records: 106,500
# 	Unique companies: 426
# 	Date range: 2023-09-05 to 2024-08-30
# 	Trading days: 250
#
# Data Quality:
# 	Overall completeness: 99.93%
#
#    Columns with missing data:
# 	   Market_Cap: 1,750 (1.6%)
#
#
# ============================================================
# PROCESSING SUMMARY
# ============================================================
#
# Status:
# 	[OK] ESG Data Cleaning
# 	[OK] Price Data Cleaning
# 	[OK] Returns Calculation
# 	[OK] Risk-Free Rate Processing
# 	[OK] Data Merging
#
# Overall: 4/4 required steps completed
#
# [SUCCESS] Data processing completed successfully!
#
# Files created:
# 	data/processed/esg_cleaned.csv
# 	data/processed/prices_cleaned.csv
# 	data/processed/returns.csv
# 	data/processed/market_returns.csv
# 	data/processed/risk_free_rate.csv
# 	data/final/master_dataset.csv
#
# Next steps:
# 	python scripts/run_feature_engineering.py
# ============================================================

# %%
# 3) Feature engineering (performance & risk metrics, controls)
# !python ../scripts/run_feature_engineering.py
# Out:
# ============================================================
# ESG STOCK PERFORMANCE ANALYSIS - FEATURE ENGINEERING
# ============================================================
#
# ### Loading Master Dataset ###
# [OK] Loaded 106500 records from data/final/master_dataset.csv
# 	Tickers: 426
# 	Date range: 2023-09-05 00:00:00+00:00 to 2024-08-30 00:00:00+00:00
#
#
# ### STEP 1/4: Performance Metrics ###
# ============================================================
# Calculating Performance Metrics
# ============================================================
#
# [INFO] Input data:
# 	Total records: 106500
# 	Tickers: 426
#
# [PROCESSING] Calculating metrics for each ticker...
#
# [OK] Calculated metrics for 426 tickers
#
# [STATS] Performance Metrics Summary:
#
# Sharpe Ratio:
# 	Mean: 0.5715
# 	Median: 0.5999
# 	Std: 0.8359
# 	Min: -1.8942
# 	Max: 2.8160
#
# Annualized Excess Return:
# 	Mean: 13.06%
# 	Median: 14.49%
# 	Min: -87.70%
# 	Max: 98.04%
#
# Cumulative Return:
# 	Mean: 18.54%
# 	Median: 17.28%
# 	Min: -60.52%
# 	Max: 146.08%
#
# [INFO] Sample results:
#   Ticker  Sharpe_Ratio  ...  Cumulative_Return  Trading_Days
# 0      A      0.526943  ...           0.172340           250
# 1    AAL     -0.739090  ...          -0.276567           250
# 2   AAPL      0.726335  ...           0.208698           250
# 3   ABBV      1.300788  ...           0.324629           250
# 4    ABT      0.327600  ...           0.101313           250
# 5   ACGL      1.621150  ...           0.468510           250
# 6    ACN      0.067020  ...           0.043358           250
# 7   ADBE      0.070622  ...           0.019886           250
# 8    ADI      0.824048  ...           0.287288           250
# 9    ADM     -0.800391  ...          -0.235618           250
#
# [10 rows x 5 columns]
#
# [SAVED] Performance metrics saved to: data/processed/performance_metrics.csv
#
#
# ### STEP 2/4: Risk Metrics ###
# ============================================================
# Calculating Risk Metrics
# ============================================================
#
# [INFO] Input data:
# 	Total records: 106500
# 	Tickers: 426
#
# [PROCESSING] Calculating metrics for each ticker...
#
# [OK] Calculated metrics for 426 tickers
#
# [STATS] Risk Metrics Summary:
#
# Volatility (Annualized):
# 	Mean: 26.00%
# 	Median: 24.07%
# 	Min: 13.39%
# 	Max: 64.50%
#
# Beta:
# 	Mean: 0.7921
# 	Median: 0.7635
# 	Min: -0.2557
# 	Max: 2.5604
# 	% with Beta > 1 (more volatile than market): 28.2%
#
# Downside Deviation:
# 	Mean: 18.34%
# 	Median: 16.74%
#
# Max Drawdown:
# 	Mean: -19.99%
# 	Median: -17.89%
# 	Worst: -65.29%
#
# [INFO] Sample results:
#   Ticker  Volatility      Beta  Downside_Deviation  Max_Drawdown
# 0      A    0.274830  0.909428            0.194684     -0.188955
# 1    AAL    0.403028  1.501904            0.291972     -0.409439
# 2   AAPL    0.224149  1.007151            0.143515     -0.167129
# 3   ABBV    0.191092  0.301399            0.149716     -0.149973
# 4    ABT    0.188718  0.239371            0.130817     -0.172702
# 5   ACGL    0.221314  0.208638            0.150189     -0.184222
# 6    ACN    0.225688  0.758870            0.180374     -0.271769
# 7   ADBE    0.338035  1.305943            0.270305     -0.308369
# 8    ADI    0.297525  1.543467            0.172044     -0.175770
# 9    ADM    0.329773  0.444900            0.365269     -0.362926
#
# [SAVED] Risk metrics saved to: data/processed/risk_metrics.csv
#
#
# ### STEP 3/4: Control Variables ###
# ============================================================
# Creating Control Variables
# ============================================================
#
# [INFO] Input data:
# 	Companies: 426
#
# [PROCESSING] Creating log market cap...
# 	[WARNING]  Missing market cap for 7 companies
# 	[OK] Created log market cap for 419 companies
#
#    Market Cap Distribution:
# 	   Mean: $134.46B
# 	   Median: $39.55B
# 	   Min: $1.64B
# 	   Max: $4517.59B
#
#    Log Market Cap Distribution:
# 	   Mean: 3.8610
# 	   Std: 1.1870
#
# [PROCESSING] Creating sector dummy variables...
# 	Sectors found: 12
#
#    Sector distribution:
# 	   Technology: 61
# 	   Financial Services: 60
# 	   Industrials: 57
# 	   Healthcare: 51
# 	   Consumer Cyclical: 51
# 	   Consumer Defensive: 33
# 	   Utilities: 28
# 	   Real Estate: 28
# 	   Basic Materials: 19
# 	   Energy: 18
# 	   Communication Services: 13
# 	   Unknown: 7
#
#    [OK] Created 11 sector dummies (dropped first as baseline)
#
# ============================================================
# CONTROL VARIABLES SUMMARY
# ============================================================
# Total companies: 426
# Total variables: 13
#
# Columns created: ['Ticker', 'Market_Cap_Billions', 'Log_Market_Cap', 'Sector_Communication Services', 'Sector_Consumer Cyclical', 'Sector_Consumer Defensive', 'Sector_Energy', 'Sector_Financial Services', 'Sector_Healthcare', 'Sector_Industrials', 'Sector_Real Estate', 'Sector_Technology', 'Sector_Unknown', 'Sector_Utilities']
#
# [INFO] Sample results:
#      Ticker  Market_Cap_Billions  ...  Sector_Unknown  Sector_Utilities
# 0         A            40.381800  ...               0                 0
# 250     AAL             9.808885  ...               0                 0
# 500    AAPL          4123.996193  ...               0                 0
# 750    ABBV           394.338828  ...               0                 0
# 1000    ABT           212.492632  ...               0                 0
# 1250   ACGL            33.940654  ...               0                 0
# 1500    ACN           165.990236  ...               0                 0
# 1750   ADBE           143.854698  ...               0                 0
# 2000    ADI           136.677155  ...               0                 0
# 2250    ADM            27.844209  ...               0                 0
#
# [10 rows x 14 columns]
#
# [SAVED] Control variables saved to: data/processed/control_variables.csv
#
#
# ### STEP 4/4: Aggregate All Features ###
# ============================================================
# Aggregating All Features
# ============================================================
#
# [LOADING] Loading master dataset from: data/final/master_dataset.csv
#
# [PROCESSING] Extracting ESG scores (one row per ticker)...
# 	[OK] ESG data: 426 companies
# 	ESG columns: ['environmentScore', 'socialScore', 'governanceScore', 'totalEsg', 'ratingYear', 'ratingMonth']
#
# [PROCESSING] Merging performance metrics...
# 	Performance data: 426 companies
# 	After merge: 426 companies
#
# [PROCESSING] Merging risk metrics...
# 	Risk data: 426 companies
# 	After merge: 426 companies
#
# [PROCESSING] Merging control variables...
# 	Controls data: 426 companies
# 	After merge: 426 companies
#
# [CHECKING] Final validation...
#
# [INFO] Missing value summary:
# 	Market_Cap_Billions: 7 (1.6%)
# 	Log_Market_Cap: 7 (1.6%)
#
# ============================================================
# AGGREGATION SUMMARY
# ============================================================
# Final dataset:
# 	Companies: 426
# 	Variables: 33
# 	Completeness: 99.90%
#
# Column categories:
# 	ESG variables: 3
# 	Performance variables: 7
# 	Risk variables: 5
# 	Control variables: 13
#
# [OK] Analysis dataset saved to: data/final/analysis_dataset.csv
#
# Data preview:
#   Ticker  environmentScore  ...  Sector_Unknown  Sector_Utilities
# 0      A              1.12  ...               0                 0
# 1    AAL              9.94  ...               0                 0
# 2   AAPL              0.46  ...               0                 0
# 3   ABBV              2.38  ...               0                 0
# 4    ABT              2.27  ...               0                 0
#
# [5 rows x 33 columns]
#
# All columns:
# 	1. Ticker
# 	2. environmentScore
# 	3. socialScore
# 	4. governanceScore
# 	5. totalEsg
# 	6. ratingYear
# 	7. ratingMonth
# 	8. Trading_Days
# 	9. Mean_Daily_Excess_Return
# 	10. Annualized_Excess_Return
# 	11. Sharpe_Ratio
# 	12. Cumulative_Return
# 	13. Annualized_Return
# 	14. Mean_Daily_Return
# 	15. Volatility
# 	16. Beta
# 	17. Downside_Deviation
# 	18. Excess_Return_Std
# 	19. VaR_5pct
# 	20. Max_Drawdown
# 	21. Market_Cap_Billions
# 	22. Log_Market_Cap
# 	23. Sector_Communication Services
# 	24. Sector_Consumer Cyclical
# 	25. Sector_Consumer Defensive
# 	26. Sector_Energy
# 	27. Sector_Financial Services
# 	28. Sector_Healthcare
# 	29. Sector_Industrials
# 	30. Sector_Real Estate
# 	31. Sector_Technology
# 	32. Sector_Unknown
# 	33. Sector_Utilities
#
#
# ============================================================
# FEATURE ENGINEERING SUMMARY
# ============================================================
#
# [SUCCESS] All steps completed successfully!
#
# Files created:
# 	data/processed/performance_metrics.csv
# 	data/processed/risk_metrics.csv
# 	data/processed/control_variables.csv
# 	data/final/analysis_dataset.csv
#
# Final analysis dataset:
# 	Companies: 426
# 	Variables: 33
#
# Key metrics available:
# 	[OK] Sharpe Ratio (DV for RQ1)
# 	[OK] Volatility (DV for RQ2)
# 	[OK] ESG Score (IV)
# 	[OK] E, S, G Pillars (IV for RQ3)
# 	[OK] Log Market Cap (control)
# 	[OK] Sector Dummies (control)
#
# Next steps:
# 	python scripts/run_analysis.py
# ============================================================

# %%
# 4) Analysis (OLS regressions for RQ1-3)
# !python ../scripts/run_analysis.py
# Out:
# ============================================================
# ESG STOCK PERFORMANCE ANALYSIS - STATISTICAL ANALYSIS
# ============================================================
#
# ### Loading Analysis Dataset ###
# [OK] Loaded 426 companies from data/final/analysis_dataset.csv
#
# Columns: 33
# Sample: ['Ticker', 'environmentScore', 'socialScore', 'governanceScore', 'totalEsg', 'ratingYear', 'ratingMonth', 'Trading_Days', 'Mean_Daily_Excess_Return', 'Annualized_Excess_Return']...
#
#
# ================================================================================
# RESEARCH QUESTION 1
# ================================================================================
# ============================================================
# RQ1: ESG Score → Sharpe Ratio
# ============================================================
#
# [INFO] Model specification:
# 	DV: Sharpe_Ratio
# 	IV: totalEsg
# 	Controls: Log_Market_Cap + 11 sector dummies
# 	Sample size: 419 (dropped 7 due to missing values)
#
# ============================================================
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Sharpe_Ratio   R-squared:                       0.199
# Model:                            OLS   Adj. R-squared:                  0.176
# Method:                 Least Squares   F-statistic:                     8.417
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):           2.78e-14
# Time:                        20:05:21   Log-Likelihood:                -469.16
# No. Observations:                 419   AIC:                             964.3
# Df Residuals:                     406   BIC:                             1017.
# Df Model:                          12
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            -0.3412      0.268     -1.275      0.203      -0.867       0.185
# totalEsg                         -0.0044      0.007     -0.632      0.528      -0.018       0.009
# Log_Market_Cap                    0.2007      0.033      6.114      0.000       0.136       0.265
# Sector_Communication Services     0.2472      0.282      0.876      0.382      -0.308       0.802
# Sector_Consumer Cyclical          0.1031      0.210      0.491      0.624      -0.310       0.516
# Sector_Consumer Defensive        -0.1101      0.218     -0.504      0.614      -0.539       0.319
# Sector_Energy                    -0.3363      0.252     -1.335      0.183      -0.832       0.159
# Sector_Financial Services         0.7317      0.205      3.566      0.000       0.328       1.135
# Sector_Healthcare                 0.0975      0.210      0.465      0.642      -0.314       0.509
# Sector_Industrials                0.2992      0.202      1.483      0.139      -0.097       0.696
# Sector_Real Estate                0.3810      0.244      1.564      0.118      -0.098       0.860
# Sector_Technology                 0.2184      0.215      1.018      0.309      -0.203       0.640
# Sector_Unknown                         0          0        nan        nan           0           0
# Sector_Utilities                  0.4663      0.224      2.079      0.038       0.025       0.907
# ==============================================================================
# Omnibus:                        1.157   Durbin-Watson:                   1.787
# Prob(Omnibus):                  0.561   Jarque-Bera (JB):                1.155
# Skew:                           0.127   Prob(JB):                        0.561
# Kurtosis:                       2.960   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# ============================================================
#
# [KEY] Key Results:
# 	ESG coefficient: -0.004397
# 	ESG p-value: 0.5279
# 	Significant at 5%: [NO]
# 	R-squared: 0.1992
#
# [SAVED] Results saved to: outputs/tables/rq1_results.txt
#
#
# ================================================================================
# RESEARCH QUESTION 2
# ================================================================================
#
#
# ============================================================
# RQ2: ESG Score → Volatility
# ============================================================
#
# [INFO] Model specification:
# 	DV: Volatility
# 	IV: totalEsg
# 	Controls: Log_Market_Cap + 11 sector dummies
# 	Sample size: 419
#
# ============================================================
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Volatility   R-squared:                       0.146
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     5.797
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):           2.74e-09
# Time:                        20:05:21   Log-Likelihood:                 508.91
# No. Observations:                 419   AIC:                            -991.8
# Df Residuals:                     406   BIC:                            -939.3
# Df Model:                          12
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             0.2715      0.026     10.475      0.000       0.221       0.323
# totalEsg                          0.0016      0.001      2.358      0.019       0.000       0.003
# Log_Market_Cap                   -0.0084      0.003     -2.644      0.009      -0.015      -0.002
# Sector_Communication Services    -0.0128      0.027     -0.467      0.641      -0.067       0.041
# Sector_Consumer Cyclical          0.0250      0.020      1.226      0.221      -0.015       0.065
# Sector_Consumer Defensive        -0.0512      0.021     -2.423      0.016      -0.093      -0.010
# Sector_Energy                    -0.0483      0.024     -1.980      0.048      -0.096      -0.000
# Sector_Financial Services        -0.0351      0.020     -1.765      0.078      -0.074       0.004
# Sector_Healthcare                -0.0129      0.020     -0.637      0.525      -0.053       0.027
# Sector_Industrials               -0.0288      0.020     -1.473      0.142      -0.067       0.010
# Sector_Real Estate               -0.0167      0.024     -0.710      0.478      -0.063       0.030
# Sector_Technology                 0.0343      0.021      1.648      0.100      -0.007       0.075
# Sector_Unknown                         0          0        nan        nan           0           0
# Sector_Utilities                 -0.0713      0.022     -3.280      0.001      -0.114      -0.029
# ==============================================================================
# Omnibus:                      121.095   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              352.226
# Skew:                           1.355   Prob(JB):                     3.27e-77
# Kurtosis:                       6.583   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# ============================================================
#
# [KEY] Key Results:
# 	ESG coefficient: 0.001590
# 	ESG p-value: 0.0188
# 	Significant at 5%: [YES]
# 	Interpretation: Higher ESG → Higher volatility
# 	R-squared: 0.1463
#
# [SAVED] Results saved to: outputs/tables/rq2_results.txt
#
#
# ================================================================================
# RESEARCH QUESTION 3
# ================================================================================
#
#
# ============================================================
# RQ3: ESG Pillars (E, S, G) → Performance & Risk
# ============================================================
#
# [INFO] Using pillars:
# 	E: environmentScore
# 	S: socialScore
# 	G: governanceScore
#
# --- Model 3a: Sharpe Ratio ~ E + S + G ---
# 	Sample size: 419
#
# ============================================================
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Sharpe_Ratio   R-squared:                       0.201
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     7.249
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):           1.69e-13
# Time:                        20:05:21   Log-Likelihood:                -468.75
# No. Observations:                 419   AIC:                             967.5
# Df Residuals:                     404   BIC:                             1028.
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            -0.3595      0.284     -1.266      0.206      -0.918       0.199
# environmentScore                  0.0040      0.013      0.318      0.751      -0.021       0.029
# socialScore                      -0.0054      0.014     -0.399      0.690      -0.032       0.021
# governanceScore                  -0.0203      0.026     -0.770      0.442      -0.072       0.031
# Log_Market_Cap                    0.2085      0.034      6.126      0.000       0.142       0.275
# Sector_Communication Services     0.3394      0.309      1.100      0.272      -0.267       0.946
# Sector_Consumer Cyclical          0.1453      0.225      0.647      0.518      -0.296       0.587
# Sector_Consumer Defensive        -0.0905      0.230     -0.393      0.695      -0.543       0.362
# Sector_Energy                    -0.3781      0.257     -1.473      0.142      -0.883       0.127
# Sector_Financial Services         0.8754      0.262      3.338      0.001       0.360       1.391
# Sector_Healthcare                 0.1976      0.252      0.783      0.434      -0.298       0.694
# Sector_Industrials                0.3343      0.218      1.530      0.127      -0.095       0.764
# Sector_Real Estate                0.4372      0.252      1.733      0.084      -0.059       0.933
# Sector_Technology                 0.2650      0.226      1.173      0.241      -0.179       0.709
# Sector_Unknown                         0          0        nan        nan           0           0
# Sector_Utilities                  0.4542      0.230      1.978      0.049       0.003       0.906
# ==============================================================================
# Omnibus:                        1.193   Durbin-Watson:                   1.784
# Prob(Omnibus):                  0.551   Jarque-Bera (JB):                1.225
# Skew:                           0.128   Prob(JB):                        0.542
# Kurtosis:                       2.934   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# ============================================================
#
# [KEY] Pillar Coefficients (Sharpe Ratio):
# 	E: 0.004046 (p=0.7508)
# 	S: -0.005415 (p=0.6901)
# 	G: -0.020260 (p=0.4417)
# 	Dominant: G
#
# --- Model 3b: Volatility ~ E + S + G ---
# 	Sample size: 419
#
# ============================================================
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1966: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Volatility   R-squared:                       0.155
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     5.289
# Date:                Mon, 08 Dec 2025   Prob (F-statistic):           2.95e-09
# Time:                        20:05:21   Log-Likelihood:                 511.04
# No. Observations:                 419   AIC:                            -992.1
# Df Residuals:                     404   BIC:                            -931.5
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             0.2565      0.027      9.360      0.000       0.203       0.310
# environmentScore                  0.0017      0.001      1.400      0.162      -0.001       0.004
# socialScore                      -0.0004      0.001     -0.313      0.754      -0.003       0.002
# governanceScore                   0.0062      0.003      2.441      0.015       0.001       0.011
# Log_Market_Cap                   -0.0090      0.003     -2.742      0.006      -0.015      -0.003
# Sector_Communication Services    -0.0086      0.030     -0.290      0.772      -0.067       0.050
# Sector_Consumer Cyclical          0.0326      0.022      1.504      0.133      -0.010       0.075
# Sector_Consumer Defensive        -0.0405      0.022     -1.821      0.069      -0.084       0.003
# Sector_Energy                    -0.0446      0.025     -1.800      0.073      -0.093       0.004
# Sector_Financial Services        -0.0448      0.025     -1.769      0.078      -0.095       0.005
# Sector_Healthcare                -0.0066      0.024     -0.273      0.785      -0.054       0.041
# Sector_Industrials               -0.0186      0.021     -0.883      0.378      -0.060       0.023
# Sector_Real Estate               -0.0194      0.024     -0.798      0.425      -0.067       0.028
# Sector_Technology                 0.0384      0.022      1.763      0.079      -0.004       0.081
# Sector_Unknown                         0          0        nan        nan           0           0
# Sector_Utilities                 -0.0621      0.022     -2.802      0.005      -0.106      -0.019
# ==============================================================================
# Omnibus:                      119.003   Durbin-Watson:                   2.047
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              332.348
# Skew:                           1.348   Prob(JB):                     6.78e-73
# Kurtosis:                       6.431   Cond. No.                          inf
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# ============================================================
#
# [KEY] Pillar Coefficients (Volatility):
# 	E: 0.001720 (p=0.1624)
# 	S: -0.000410 (p=0.7542)
# 	G: 0.006197 (p=0.0151)
# 	Dominant: G
#
# [SAVED] Results saved to: outputs/tables
#
#
# ================================================================================
# DIAGNOSTIC TESTS
# ================================================================================
#
# ============================================================
# DIAGNOSTIC TESTS: RQ1: Sharpe ~ ESG
# ============================================================
#
# [CHECKING] 1. Heteroskedasticity Test (Breusch-Pagan)
# 	H0: Homoskedasticity (constant variance)
# 	H1: Heteroskedasticity (non-constant variance)
# 	LM Statistic: 15.3913
# 	p-value: 0.2836
# 	[OK] FAIL TO REJECT H0: No evidence of heteroskedasticity
#
# [CHECKING] 2. Multicollinearity (Variance Inflation Factor)
# 	Rule of thumb: VIF > 10 indicates problematic multicollinearity
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#
#    VIF values:
# 	[WARNING] const: 52.88
# 	[OK] totalEsg: 1.68
# 	[OK] Log_Market_Cap: 1.12
# 	[OK] Sector_Communication Services: 1.77
# 	[OK] Sector_Consumer Cyclical: 3.49
# 	[OK] Sector_Consumer Defensive: 2.55
# 	[OK] Sector_Energy: 1.93
# 	[OK] Sector_Financial Services: 3.82
# 	[OK] Sector_Healthcare: 3.47
# 	[OK] Sector_Industrials: 3.53
# 	[OK] Sector_Real Estate: 2.73
# 	[OK] Sector_Technology: 4.23
# 	[OK] Sector_Unknown: nan
# 	[OK] Sector_Utilities: 2.32
#
#    [WARNING] 1 variables with VIF > 10
# 	→ Recommendation: Consider removing highly correlated variables
#
# [CHECKING] 3. Normality of Residuals (Jarque-Bera Test)
# 	H0: Residuals are normally distributed
# 	H1: Residuals are not normally distributed
# 	[ERROR] Error running test: not enough values to unpack (expected 4, got 2)
#
# [INFO] Additional Diagnostics:
# 	R-squared: 0.1992
# 	Adjusted R-squared: 0.1755
# 	F-statistic: 8.4170 (p=2.7812e-14)
# 	AIC: 964.31
# 	BIC: 1016.80
#
# ============================================================
# RECOMMENDATIONS:
# ============================================================
# [OK] Standard errors appear valid
# [WARNING] Consider variable selection to reduce multicollinearity
# [INFO] Residuals non-normal, but OLS is robust with large samples (n > 30)
#
# ============================================================
# DIAGNOSTIC TESTS: RQ2: Volatility ~ ESG
# ============================================================
#
# [CHECKING] 1. Heteroskedasticity Test (Breusch-Pagan)
# 	H0: Homoskedasticity (constant variance)
# 	H1: Heteroskedasticity (non-constant variance)
# 	LM Statistic: 13.5728
# 	p-value: 0.4046
# 	[OK] FAIL TO REJECT H0: No evidence of heteroskedasticity
#
# [CHECKING] 2. Multicollinearity (Variance Inflation Factor)
# 	Rule of thumb: VIF > 10 indicates problematic multicollinearity
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#
#    VIF values:
# 	[WARNING] const: 52.88
# 	[OK] totalEsg: 1.68
# 	[OK] Log_Market_Cap: 1.12
# 	[OK] Sector_Communication Services: 1.77
# 	[OK] Sector_Consumer Cyclical: 3.49
# 	[OK] Sector_Consumer Defensive: 2.55
# 	[OK] Sector_Energy: 1.93
# 	[OK] Sector_Financial Services: 3.82
# 	[OK] Sector_Healthcare: 3.47
# 	[OK] Sector_Industrials: 3.53
# 	[OK] Sector_Real Estate: 2.73
# 	[OK] Sector_Technology: 4.23
# 	[OK] Sector_Unknown: nan
# 	[OK] Sector_Utilities: 2.32
#
#    [WARNING] 1 variables with VIF > 10
# 	→ Recommendation: Consider removing highly correlated variables
#
# [CHECKING] 3. Normality of Residuals (Jarque-Bera Test)
# 	H0: Residuals are normally distributed
# 	H1: Residuals are not normally distributed
# 	[ERROR] Error running test: not enough values to unpack (expected 4, got 2)
#
# [INFO] Additional Diagnostics:
# 	R-squared: 0.1463
# 	Adjusted R-squared: 0.1210
# 	F-statistic: 5.7968 (p=2.7446e-09)
# 	AIC: -991.82
# 	BIC: -939.33
#
# ============================================================
# RECOMMENDATIONS:
# ============================================================
# [OK] Standard errors appear valid
# [WARNING] Consider variable selection to reduce multicollinearity
# [INFO] Residuals non-normal, but OLS is robust with large samples (n > 30)
#
#
# ================================================================================
# SUMMARY OF FINDINGS
# ================================================================================
#
# [INFO] RQ1: ESG Score → Sharpe Ratio
# 	Coefficient: -0.004397
# 	P-value: 0.5279
# 	Significant: [NO]
# 	R²: 0.1992
# 	Interpretation: Higher ESG → Lower risk-adjusted returns
#
# [INFO] RQ2: ESG Score → Volatility
# 	Coefficient: 0.001590
# 	P-value: 0.0188
# 	Significant: [YES]
# 	R²: 0.1463
# 	Interpretation: Higher ESG → Higher volatility (less stable)
#
# [INFO] RQ3a: ESG Pillars → Sharpe Ratio
# 	E coefficient: 0.004046 (p=0.7508)
# 	S coefficient: -0.005415 (p=0.6901)
# 	G coefficient: -0.020260 (p=0.4417)
# 	Dominant pillar: G
#
# [INFO] RQ3b: ESG Pillars → Volatility
# 	E coefficient: 0.001720 (p=0.1624)
# 	S coefficient: -0.000410 (p=0.7542)
# 	G coefficient: 0.006197 (p=0.0151)
# 	Dominant pillar: G
#
# [SAVED] Summary saved to: outputs/tables/analysis_summary.txt
#
# ================================================================================
# [SUCCESS] ANALYSIS COMPLETE
# ================================================================================
#
# Results saved to: outputs/tables

# %%
# 5) Figures (diagnostic and result plots)
# !python ../scripts/create_diagnostic_plots.py
# Out:
# ============================================================
# REGRESSION DIAGNOSTICS VISUALIZATION
# ============================================================
#
# ### Loading Data ###
# Loaded 426 companies
#
# ============================================================
# RQ1: ESG Score → Sharpe Ratio
# ============================================================
#
# [INFO] Creating diagnostic plots for RQ1 Sharpe Ratio...
#    Saved to: outputs/figures/diagnostics/rq1_sharpe_ratio_diagnostics.png
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#
# [INFO] Creating VIF plot for RQ1 Sharpe Ratio...
#    Saved to: outputs/figures/diagnostics/rq1_sharpe_ratio_vif.png
#
# ============================================================
# RQ2: ESG Score → Volatility
# ============================================================
#
# [INFO] Creating diagnostic plots for RQ2 Volatility...
#    Saved to: outputs/figures/diagnostics/rq2_volatility_diagnostics.png
# /Users/ayush/Desktop/DATA 512/esg-stock-performace-impact/venv/lib/python3.14/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#
# [INFO] Creating VIF plot for RQ2 Volatility...
#    Saved to: outputs/figures/diagnostics/rq2_volatility_vif.png
#
# ============================================================
# DIAGNOSTIC PLOTS COMPLETE
# ============================================================
#
# Plots saved to: outputs/figures/diagnostics
#
# Generated files:
#   - rq1_sharpe_ratio_diagnostics.png (4-panel diagnostic)
#   - rq1_sharpe_ratio_vif.png (multicollinearity)
#   - rq2_volatility_diagnostics.png (4-panel diagnostic)
#   - rq2_volatility_vif.png (multicollinearity)

# %% [markdown]
# ## Verify key artifacts
# - Final analysis dataset: `../data/final/analysis_dataset.csv`
# - Tables: `../outputs/tables/`
# - Figures: `../outputs/figures/`

# %%
import pandas as pd
from pathlib import Path

analysis_path = Path("../data/final/analysis_dataset.csv")
if analysis_path.exists():
    df = pd.read_csv(analysis_path)
    display(df.head())
    print(f"Rows: {len(df)}, Columns: {len(df.columns)}")
else:
    print("analysis_dataset.csv not found. Re-run scripts above and verify Kaggle/FRED access.")
# Out:
#   Ticker  environmentScore  socialScore  governanceScore  totalEsg  \
# 0      A              1.12         6.42             6.10     13.64
# 1    AAL              9.94        11.65             4.76     26.35
# 2   AAPL              0.46         7.39             9.37     17.22
# 3   ABBV              2.38        17.19            10.36     29.93
# 4    ABT              2.27        14.24             8.33     24.83
#
#    ratingYear  ratingMonth  Trading_Days  Mean_Daily_Excess_Return  \
# 0      2023.0          9.0           250                  0.000575
# 1      2023.0          9.0           250                 -0.001182
# 2      2023.0          9.0           250                  0.000646
# 3      2023.0          9.0           250                  0.000986
# 4      2023.0          9.0           250                  0.000245
#
#    Annualized_Excess_Return  ...  Sector_Consumer Cyclical  \
# 0                  0.144821  ...                         0
# 1                 -0.297876  ...                         0
# 2                  0.162807  ...                         0
# 3                  0.248576  ...                         0
# 4                  0.061825  ...                         0
#
#    Sector_Consumer Defensive  Sector_Energy  Sector_Financial Services  \
# 0                          0              0                          0
# 1                          0              0                          0
# 2                          0              0                          0
# 3                          0              0                          0
# 4                          0              0                          0
#
#    Sector_Healthcare  Sector_Industrials  Sector_Real Estate  \
# 0                  1                   0                   0
# 1                  0                   1                   0
# 2                  0                   0                   0
# 3                  1                   0                   0
# 4                  1                   0                   0
#
#    Sector_Technology  Sector_Unknown  Sector_Utilities
# 0                  0               0                 0
# 1                  0               0                 0
# 2                  1               0                 0
# 3                  0               0                 0
# 4                  0               0                 0
#
# [5 rows x 33 columns]
# Rows: 426, Columns: 33

# %% [markdown]
# ## RQ Interpretations (quick reference)
# - **RQ1 – Returns (Sharpe):** ESG coefficient -0.0043 (p=0.535, R²≈0.20) → no evidence that higher ESG improves risk-adjusted returns.
# - **RQ2 – Volatility:** ESG coefficient +0.0016 (p=0.018, R²≈0.15) → higher ESG associates with slightly higher volatility; contrary to de-risking claims.
# - **RQ3 – Pillars:** Governance drives the volatility effect (+0.0063, p=0.013); Environment/Social not significant for returns or volatility.
# - **Implication:** ESG scores alone do not deliver near-term risk-adjusted outperformance in this window and may coincide with marginally higher risk; governance is the only pillar with a detectable volatility link.
